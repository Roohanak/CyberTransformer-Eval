# %% [markdown]
# # MiniLM Eval Lab\n\nThis notebook is a lightweight experiment log for the CyberTransformer-Eval project. Run the scripts from the terminal first, then use this notebook to inspect metrics and plots.

# %%
import json\nfrom pathlib import Path\n\nmetrics_path = Path('../results/metrics.json')\nif metrics_path.exists():\n    metrics = json.loads(metrics_path.read_text())\n    metrics\nelse:\n    print('Run python -m src.train first.')

# %%
from IPython.display import Image, display\ncm_path = Path('../results/confusion_matrix.png')\nif cm_path.exists():\n    display(Image(filename=str(cm_path)))\nelse:\n    print('No confusion matrix yet.')
